# %%
import pandas as pd
df = pd.read_csv("C:/Users/17162/source/repos/BasedOctavian/StatTools/Data/Cleaned Data V2.csv")
df
# Out:
#     FighterGrade  BodyKicksAbsorbed  ClinchStrikeHiMake  ClinchStrikeHiMiss  \
# 0           73.0           0.027397            0.027397            0.013699
# 1           86.0           0.120000            0.160000            0.000000
# 2           81.0           0.095890            0.041096            0.013699
# 3           78.0           0.176471            0.000000            0.000000
# 4           86.0           0.325581            0.325581            0.069767
# ..           ...                ...                 ...                 ...
# 84          79.0           0.133333            0.000000            0.000000
# 85          89.0           0.141509            0.009434            0.000000
# 86          71.0           0.333333            1.600000            0.333333
# 87          77.0           0.133333            0.000000            0.000000
# 88          80.0           0.000000            0.666667            0.102564
#
# ...

# %%
df.isnull().sum()
# Out:
# FighterGrade            0
# BodyKicksAbsorbed       0
# ClinchStrikeHiMake      0
# ClinchStrikeHiMiss      0
# ClinchStrikeLoMake      0
#                        ..
# TotalStrikesLanded      0
# TotalUppercutsMade      0
# TotalUppercutsMissed    0
# TotalUppercutsThrown    0
# UppercutsAbsorbed       0
# Length: 119, dtype: int64

# %%
x = df.drop(columns = 'FighterGrade')
x
# Out:
#     BodyKicksAbsorbed  ClinchStrikeHiMake  ClinchStrikeHiMiss  \
# 0            0.027397            0.027397            0.013699
# 1            0.120000            0.160000            0.000000
# 2            0.095890            0.041096            0.013699
# 3            0.176471            0.000000            0.000000
# 4            0.325581            0.325581            0.069767
# ..                ...                 ...                 ...
# 84           0.133333            0.000000            0.000000
# 85           0.141509            0.009434            0.000000
# 86           0.333333            1.600000            0.333333
# 87           0.133333            0.000000            0.000000
# 88           0.000000            0.666667            0.102564
#
#     ClinchStrikeLoMake  ClinchStrikeLoMiss  DoubleLegDefends  \
# 0             0.000000                0.00          0.041096
# 1             0.200000                0.04          0.000000
# ...

# %%
y = df['FighterGrade']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
c = lr.intercept_

# %%
c
# Out:
# 88.99999999999991

# %%
m = lr.coef_
m
# Out:
# array([-19.78564673,  26.55100822, -68.38341787, -19.29762517,
#         66.91975062, -28.3825748 , -22.56499361,  -3.74471564,
#        -18.82027789,  -1.48314949,  -5.76851175,  -1.36909366,
#         12.06094822,  13.36425807,  -1.2961747 , -11.39037773,
#          6.66641721,   3.20668834,  65.85030035, -33.52380495,
#        -16.56302828,  33.92821794,  -1.16438578,  -7.68970021,
#          2.77285308,  24.653049  ,   9.95634351, -57.88266691,
#         -9.34584134, -19.11115543,  14.21533619,   2.48212286,
#         -6.52394094, -19.83599106,  90.21777287,  -0.13524329,
#         50.79675238,  -6.09296404,   4.45865178,   3.41650351,
#        -21.71517275,  -7.74327057,  74.58688764, -89.60372016,
#        -11.43445419,  -8.67917413, -21.21970011,  -7.03616934,
#         -4.43529545,   6.28638275,  38.70999186, -39.87018369,
#          3.28994441,  14.04267627, -11.28685952,  14.45502993,
#         -4.11147833,  33.10189909, -66.81058301,  46.41850143,
# ...

# %%
y_pred_train = lr.predict(x_train)

# %%
y_pred_train
# Out:
# array([86.5, 82. , 78. , 85. , 93. , 75. , 83. , 91. , 89. , 65. , 87. ,
#        67. , 86. , 71. , 82. , 69. , 70. , 83. , 88. , 72. , 73. , 77. ,
#        77. , 88. , 81. , 64. , 73. , 85. , 92. , 95. , 81. , 77. , 86. ,
#        73. , 80. , 68. , 79. , 86. , 76. , 85. , 71. , 77. , 84. , 73. ,
#        82. , 85. , 73. , 82. , 89. , 72. , 72. , 93. , 80. , 70. , 82. ,
#        78. , 78. , 89. , 87. , 81. , 84.5, 76. ])

# %%
import matplotlib.pyplot as plt
plt.scatter(y_train, y_pred_train)
plt.xlabel("Actual Fighter Grade")
plt.ylabel("Predicted Fighter Grade")
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train, y_pred_train)
# Out:
# 1.0

# %%
y_pred_test = lr.predict(x_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred_test)
plt.xlabel("Actual Fighter Grade")
plt.ylabel("Predicted Fighter Grade")
plt.show()

# %%
r2_score(y_test, y_pred_test)
# Out:
# -11.829956042033183
